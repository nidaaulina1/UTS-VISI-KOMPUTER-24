# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('visi komputer.jpg')

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=750x1000>

# %%
result = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=L size=750x1000>

# %%
ret, thresh1 = cv2.threshold(result, 50, 500, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(result, 50, 500, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(result, 50, 500, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(result, 50, 500, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(result, 50, 500, cv2.THRESH_TOZERO_INV)# 3 digit nim saya 050 jadi saya ganti menjadi 500

# %%
cv2_imshow(thresh1)
cv2_imshow(thresh2)
cv2_imshow(thresh3)
cv2_imshow(thresh4)
cv2_imshow(thresh5)
# Out:
# <PIL.Image.Image image mode=L size=750x1000>
# <PIL.Image.Image image mode=L size=750x1000>
# <PIL.Image.Image image mode=L size=750x1000>
# <PIL.Image.Image image mode=L size=750x1000>
# <PIL.Image.Image image mode=L size=750x1000>
